# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model(
    "waste_classifier_effnetB4_final.keras"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 226 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
class_names = [
    'E-waste',
    'automobile wastes',
    'battery waste',
    'glass waste',
    'light bulbs',
    'metal waste',
    'organic waste',
    'paper waste',
    'plastic waste'
]

# %%
def predict_image(img_path):
    img = tf.keras.preprocessing.image.load_img(
        img_path, target_size=(380, 380)
    )
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    img_array = tf.keras.applications.efficientnet.preprocess_input(img_array)

    preds = model.predict(img_array)
    class_id = np.argmax(preds[0])
    confidence = np.max(preds[0])

    print("Predicted class:", class_names[class_id])
    print("Confidence:", confidence)

    plt.imshow(img)
    plt.axis("off")
    plt.show()

# %%
predict_image("/content/sampemetal.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Predicted class: metal waste
# Confidence: 0.40938687

# %%
predict_image("/content/sampleorganic.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted class: organic waste
# Confidence: 0.70973045

# %%
predict_image("/content/samplepaper.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted class: paper waste
# Confidence: 0.9991698

# %%
predict_image("/content/sampleplastic.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted class: plastic waste
# Confidence: 0.9854999

# %%
predict_image("/content/sampleglass.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Predicted class: glass waste
# Confidence: 0.55984205

# %%
predict_image("/content/samplebattery.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Predicted class: battery waste
# Confidence: 0.7150291

# %%
predict_image("/content/sampleewaste.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Predicted class: E-waste
# Confidence: 0.7785416
